# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
x=[i for i in range(10)]
k=3
print(np.sin(x*k))
print
plt.plot(np.sin(x*k))
plt.plot(np.sin(x))
# Out:
# [ 0.          0.84147098  0.90929743  0.14112001 -0.7568025  -0.95892427
#  -0.2794155   0.6569866   0.98935825  0.41211849  0.          0.84147098
#   0.90929743  0.14112001 -0.7568025  -0.95892427 -0.2794155   0.6569866
#   0.98935825  0.41211849  0.          0.84147098  0.90929743  0.14112001
#  -0.7568025  -0.95892427 -0.2794155   0.6569866   0.98935825  0.41211849]
